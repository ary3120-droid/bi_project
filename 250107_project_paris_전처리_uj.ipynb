# %%
# Data Source: Inside Airbnb
# Snapshot: June 2025
# File: listings.csv (summary, 18 columns)
# Goal: city-level preprocessing + light EDA
# Note: Do NOT drop columns, row-level cleaning only

# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#데이터로드 및 데이터크기 확인
import pandas as pd

path = '/content/drive/MyDrive/paris_listings_clean.csv'
df = pd.read_csv(path, low_memory=False)

df.shape
# Out:
# (53963, 18)

# %%
df.head()
# Out:
#       id                                             name  host_id  \
# 0   3109                                     zen and calm     3631
# 1   5396     Your perfect Paris studio on Île Saint-Louis     7903
# 2   7397                 MARAIS - 2ROOMS APT - 2/4 PEOPLE     2626
# 3   9359  Cozy, Central Paris: WALK or VELIB EVERYWHERE !    28422
# 4  11265                 Elegant appartment in Montmartre    41718
#
#     host_name      neighbourhood  latitude  longitude        room_type  price  \
# 0        Anne       Observatoire  48.83191    2.31870  Entire home/apt  135.0
# 1      Borzou     Hôtel-de-Ville  48.85247    2.35835  Entire home/apt  114.0
# 2      Franck     Hôtel-de-Ville  48.85909    2.35315  Entire home/apt  149.0
# 3  Bernadette             Louvre  48.86006    2.34863  Entire home/apt   75.0
# 4      Sylvie  Buttes-Montmartre  48.88494    2.33997  Entire home/apt  150.0
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               2                  7  2025-06-03               0.08
# 1               1                452  2025-06-05               2.32
# 2              10                380  2025-06-03               2.20
# 3             180                  0         NaN               0.00
# 4               7                 35  2025-05-31               0.32
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               1               355                      3
# 1                               1                69                     48
# 2                               1               197                     25
# 3                               1               358                      0
# 4                               1                59                      5
#
#                                              license review_group
# 0                                      7511409139079  Has Reviews
# 1                                      7510402838018  Has Reviews
# 2                                      7510400829623  Has Reviews
# 3  Available with a mobility lease only ("bail mo...   No Reviews
# 4                                      7511801401834  Has Reviews

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53963 entries, 0 to 53962
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              53963 non-null  int64
#  1   name                            53963 non-null  object
#  2   host_id                         53963 non-null  int64
#  3   host_name                       53953 non-null  object
#  4   neighbourhood                   53963 non-null  object
#  5   latitude                        53963 non-null  float64
#  6   longitude                       53963 non-null  float64
#  7   room_type                       53963 non-null  object
#  8   price                           53963 non-null  float64
#  9   minimum_nights                  53963 non-null  int64
#  10  number_of_reviews               53963 non-null  int64
#  11  last_review                     42306 non-null  object
#  12  reviews_per_month               53963 non-null  float64
#  13  calculated_host_listings_count  53963 non-null  int64
#  14  availability_365                53963 non-null  int64
#  15  number_of_reviews_ltm           53963 non-null  int64
#  16  license                         48239 non-null  object
#  17  review_group                    53963 non-null  object
# dtypes: float64(4), int64(7), object(7)
# memory usage: 7.4+ MB

# %%
# 다른 csv 파일과 동일한 전처리 적용
# 1) price 결측 제거
df = df.dropna(subset=["price"])

# 2) 리뷰 결측 = 리뷰 없음
df["reviews_per_month"] = df["reviews_per_month"].fillna(0)

# 3) EUR -> USD 환율 (2025-06-05 매매기준율)
EUR_TO_USD_20250605 = 1570 / 1373.80  # ≈ 1.142

# 4) price_usd 생성 (소수점 1자리)
df["price_usd"] = (df["price"] * EUR_TO_USD_20250605).round(1)

# %%
df.isna().mean().sort_values(ascending=False).head(6)
df[["price", "price_usd"]].describe()
# Out:
#               price     price_usd
# count  53963.000000  53963.000000
# mean     285.263384    326.004816
# std      688.616441    786.960942
# min        8.000000      9.100000
# 25%      104.000000    118.900000
# 50%      161.000000    184.000000
# 75%      277.000000    316.600000
# max    30814.000000  35214.700000

# %%
 # 저장 전 점검(핵심만)
print(df.isna().mean().sort_values(ascending=False).head(6))
print(df[["price", "price_usd"]].describe())
# Out:
# last_review    0.216018
# license        0.106073
# host_name      0.000185
# host_id        0.000000
# name           0.000000
# id             0.000000
# dtype: float64
#               price     price_usd
# count  53963.000000  53963.000000
# mean     285.263384    326.004816
# std      688.616441    786.960942
# min        8.000000      9.100000
# 25%      104.000000    118.900000
# 50%      161.000000    184.000000
# 75%      277.000000    316.600000
# max    30814.000000  35214.700000

# %%
df["price_usd"] = df["price_usd"].round(1)

# %%
print("price <= 0:", (df["price"] <= 0).sum())
print("price_usd <= 0:", (df["price_usd"] <= 0).sum())
# Out:
# price <= 0: 0
# price_usd <= 0: 0

# %%
df.head(20)
# Out:
#        id                                               name  host_id  \
# 0    3109                                       zen and calm     3631
# 1    5396       Your perfect Paris studio on Île Saint-Louis     7903
# 2    7397                   MARAIS - 2ROOMS APT - 2/4 PEOPLE     2626
# 3    9359    Cozy, Central Paris: WALK or VELIB EVERYWHERE !    28422
# 4   11265                   Elegant appartment in Montmartre    41718
# 5   11487               Heart of  Paris, brand new aparment.    42666
# 6   11798                              Amazing Loft in Paris    44444
# 7   12452                                     Voltaire Charm    48733
# 8   14903                       SPACIEUX PARC DE LA VILLETTE    58645
# 9   16626                              Elegance in St Michel    64627
# 10  17994                            Center of paris: Louvre    69389
# 11  19029  Brand new lovely studio + balcony Sopi montmartre    72713
# 12  21004                LUXURIOUS PENTHOUSE+ 80 SQM TERRACE    79843
# 13  22158       Artist Loft with rooftop in the city center!    84874
# 14  24151         Studio entièrement rénové au cœur de Paris    89209
# 15  24260                   Lovely place near Champs Elysees    98012
# 16  25450                 PARIS 10eme Luxury 2 Bed Apartment   105570
# 17  26562                        The Tower as your neighbour   107514
# 18  27967    Nice haussmannian apt. Canal Saint-Martin area.   120508
# 19  29386  Lovely garden studio in Butte-aux-Cailles village   126361
#
#      host_name        neighbourhood   latitude  longitude        room_type  \
# 0         Anne         Observatoire  48.831910   2.318700  Entire home/apt
# 1       Borzou       Hôtel-de-Ville  48.852470   2.358350  Entire home/apt
# 2       Franck       Hôtel-de-Ville  48.859090   2.353150  Entire home/apt
# 3   Bernadette               Louvre  48.860060   2.348630  Entire home/apt
# 4       Sylvie    Buttes-Montmartre  48.884940   2.339970  Entire home/apt
# 5     Brigitte           Popincourt  48.864410   2.371390  Entire home/apt
# 6     Laurence             Gobelins  48.825241   2.367469  Entire home/apt
# 7        Irene           Popincourt  48.861590   2.379520  Entire home/apt
# 8         Fred      Buttes-Chaumont  48.882790   2.386420  Entire home/apt
# 9     Phoenice           Luxembourg  48.852200   2.341140     Private room
# 10        Reem               Louvre  48.861850   2.343400  Entire home/apt
# 11        Anna                Opéra  48.882050   2.333720  Entire home/apt
# 12       Nadia              Reuilly  48.837970   2.400580  Entire home/apt
# 13    Fabienne               Élysée  48.870390   2.322730     Private room
# 14        Rémy             Panthéon  48.844060   2.345390  Entire home/apt
# 15    Emmanuel  Batignolles-Monceau  48.880900   2.303880  Entire home/apt
# 16     Florian             Entrepôt  48.870070   2.364420  Entire home/apt
# 17      Judith            Vaugirard  48.853570   2.292320  Entire home/apt
# 18    Philippe             Entrepôt  48.870815   2.363212  Entire home/apt
# 19   Marcolino             Gobelins  48.827944   2.348952  Entire home/apt
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    135.0               2                  7  2025-06-03               0.08
# 1    114.0               1                452  2025-06-05               2.32
# 2    149.0              10                380  2025-06-03               2.20
# 3     75.0             180                  0         NaN               0.00
# 4    150.0               7                 35  2025-05-31               0.32
# 5     63.0              30                 16  2025-06-06               0.10
# 6    126.0               3                121  2023-10-21               0.78
# 7    360.0               1                 63  2025-05-24               0.73
# 8    200.0               7                  8  2012-10-24               0.05
# 9    162.0               3                176  2025-03-30               0.94
# 10  1200.0               4                202  2023-06-25               1.08
# 11    64.0              30                 91  2025-06-01               0.52
# 12   173.0               2                133  2025-04-22               0.72
# 13   150.0               2                116  2025-06-12               0.76
# 14   180.0               3                 28  2025-05-27               0.15
# 15   112.0               2                 42  2025-04-09               0.23
# 16   320.0             365                  0         NaN               0.00
# 17   200.0               4                167  2024-08-04               0.91
# 18   180.0               4                 27  2025-04-28               0.15
# 19    92.0               3                  5  2025-05-21               1.67
#
#     calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                                1               355                      3
# 1                                1                69                     48
# 2                                1               197                     25
# 3                                1               358                      0
# 4                                1                59                      5
# 5                                1               241                      5
# 6                                1               349                      0
# 7                                1                 8                      4
# 8                                1               173                      0
# 9                                3               294                     18
# 10                               1               365                      0
# 11                               1               250                      4
# 12                               8               324                      8
# 13                               1                54                     14
# 14                               1               338                      6
# 15                               3               362                     12
# 16                               1               365                      0
# 17                               1                92                      1
# 18                               1               186                      5
# 19                               1                68                      5
#
#                                               license review_group  price_usd
# 0                                       7511409139079  Has Reviews      154.3
# 1                                       7510402838018  Has Reviews      130.3
# 2                                       7510400829623  Has Reviews      170.3
# 3   Available with a mobility lease only ("bail mo...   No Reviews       85.7
# 4                                       7511801401834  Has Reviews      171.4
# 5   Available with a mobility lease only ("bail mo...  Has Reviews       72.0
# 6                         Exempt - hotel-type listing  Has Reviews      144.0
# 7                                       7511102600669  Has Reviews      411.4
# 8                                       7511911870085  Has Reviews      228.6
# 9                                                 NaN  Has Reviews      185.1
# 10                                      7510102359633  Has Reviews     1371.4
# 11  Available with a mobility lease only ("bail mo...  Has Reviews       73.1
# 12                                      7511205142339  Has Reviews      197.7
# 13                                                NaN  Has Reviews      171.4
# 14                                      7510514643384  Has Reviews      205.7
# 15                                      7511709896091  Has Reviews      128.0
# 16                                                NaN   No Reviews      365.7
# 17                                      7511500915333  Has Reviews      228.6
# 18                                      7511010572118  Has Reviews      205.7
# 19                                      7511314277633  Has Reviews      105.1

# %%
#도시필터 적용을 위해 city 컬럼 추가
df["city"] = "Paris"

# %%
save_path = "/content/drive/MyDrive/airbnb/clean/paris_listings_jun2025_summary_clean_uj.csv"
df.to_csv(save_path, index=False)
print("saved:", save_path)
# Out:
# saved: /content/drive/MyDrive/airbnb/clean/paris_listings_jun2025_summary_clean_uj.csv

# %%
print(df.shape)
df.info()
# Out:
# (53963, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53963 entries, 0 to 53962
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              53963 non-null  int64
#  1   name                            53963 non-null  object
#  2   host_id                         53963 non-null  int64
#  3   host_name                       53953 non-null  object
#  4   neighbourhood                   53963 non-null  object
#  5   latitude                        53963 non-null  float64
#  6   longitude                       53963 non-null  float64
#  7   room_type                       53963 non-null  object
#  8   price                           53963 non-null  float64
#  9   minimum_nights                  53963 non-null  int64
#  10  number_of_reviews               53963 non-null  int64
#  11  last_review                     42306 non-null  object
#  12  reviews_per_month               53963 non-null  float64
#  13  calculated_host_listings_count  53963 non-null  int64
#  14  availability_365                53963 non-null  int64
#  15  number_of_reviews_ltm           53963 non-null  int64
#  16  license                         48239 non-null  object
#  17  review_group                    53963 non-null  object
#  18  price_usd                       53963 non-null  float64
#  19  city                            53963 non-null  object
# dtypes: float64(5), int64(7), object(8)
# memory usage: 8.2+ MB
